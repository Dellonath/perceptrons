# %%
from sklearn.datasets import make_blobs
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random as rd
# %matplotlib inline

# %%
def aprendizado(tupla):
    global pesosA
    global pesosB
    global pesosC
    
    A = pow(tupla[0] - pesosA[0], 2) + pow(tupla[1] - pesosA[1], 2)
    B = pow(tupla[0] - pesosB[0], 2) + pow(tupla[1] - pesosB[1], 2)
    C = pow(tupla[0] - pesosC[0], 2) + pow(tupla[1] - pesosC[1], 2)

    if A < B and A < C:
        pesosA[0] += 0.1*(tupla[0] - pesosA[0])
        pesosA[1] += 0.1*(tupla[1] - pesosA[1])
    elif B < A and B < C:
        pesosB[0] += 0.1*(tupla[0] - pesosB[0])
        pesosB[1] += 0.1*(tupla[1] - pesosB[1])
    elif C < A and C < B:
        pesosC[0] += 0.1*(tupla[0] - pesosC[0])
        pesosC[1] += 0.1*(tupla[1] - pesosC[1])

# %%
X, y = make_blobs(n_samples=300, centers=3, n_features=2) # gerador de pontos, se a cada vez que rodar esta célula uma nova situação será criada
x1 = np.hsplit(X,2)[0].reshape(1, len(np.hsplit(X,2)[0]))[0]
x2 = np.hsplit(X,2)[1].reshape(1, len(np.hsplit(X,2)[0]))[0]

global pesosA 
pesosA = [rd.randint(-10, 10), rd.randint(-10, 10)] # pesos aleatórios de 0 a 10
global pesosB 
pesosB = [rd.randint(-10, 10), rd.randint(-10, 10)]
global pesosC
pesosC = [rd.randint(-10, 10), rd.randint(-10, 10)]

print('PesosA: ', pesosA)
print('PesosB: ', pesosB)
print('PesosC: ', pesosC)

for j in range(50):
    for i in range(len(X)):
        aprendizado(X[i])

plt.figure(figsize=(12, 7))
plt.style.use('dark_background')

sns.scatterplot(x1, x2, color = 'blue', legend = False)
sns.scatterplot([pesosA[0], pesosB[0], pesosC[0]], [pesosA[1], pesosB[1], pesosC[1]], color = 'red', s = 200, legend = False)

print('\nPesosA: ', pesosA)
print('PesosB: ', pesosB)
print('PesosC: ', pesosC)
# Out:
# PesosA:  [-5, -1]
# PesosB:  [4, 1]
# PesosC:  [4, 9]
#
# PesosA:  [-6.455284961553787, 9.151829753358713]
# PesosB:  [1.6030919638941428, -7.941396776998182]
# PesosC:  [8.628286870263095, 5.684211691329975]
